# %% [markdown]
# # Connectivity Arduino Uno R3

# %%
import serial
import time

ports={
    "matteo": "/dev/ttyACM0",
    "mike": "COM3",
}
#Per MIKE Verifica la connessione qua che su Linux potresti avere una porta diversa da Windows, ho ipotizzato fosse COM3 come standard
for user, port in ports.items():
    if not port:
        continue
    try:
        arduino=serial.Serial(port=port, baudrate=9600, timeout=1)
        print(f"Connected to {user}'s port")
        break
    except serial.SerialException:
        pass
if arduino is None:
    print("Error. Arduino not found, check in Arduino IDE")
    pass

while(True):
    line=arduino.readline().decode("utf-8").strip()
    if line:
        print(f"Received data: {line}")
    time.sleep(1)
# Out:
# Connected to matteo's port
# Received data: 409
# Received data: 409
# Received data: 409
# Received data: 408
# Received data: 408
# Received data: 408
# Received data: 408
# Received data: 408
# Received data: 409
# Received data: 409
# Received data: 409
# Received data: 409
# Received data: 409
# Received data: 408
# Received data: 408
# Received data: 408
# Received data: 409
# Received data: 409
# Received data: 409
# Received data: 408
# Received data: 408
# Received data: 408
# Received data: 409
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 26
#      22 while(True):
#      23     line=arduino.readline().decode("utf-8").strip()
#      24     if line:
#      25         print(f"Received data: {line}")
# ---> 26     time.sleep(1)
#
# KeyboardInterrupt:
